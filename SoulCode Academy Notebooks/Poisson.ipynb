# %%
import scipy.stats as sp

# %%
'''
Imagine que a chegada de pessoas em um determinado caixa eletrônico obedece
uma distribuiução de Poisson com taxa média de chegada de 12 pessoas por hora
assim calcule:

a) A probabilidade de que em uma hora qualquer cheguem 4 pessoas
lambda =  12 por hora
k =  4 por hora

b) A probabilidade de que em uma hora qualquer cheguem 7 pessoas
lambda = 12 por hora
k = 7 por hora

c) A probabilidade de que em uma hora qualquer cheguem 7 clientes ou menos
P(k <= 7) cdf direto pois cdf por padrão de um ponto para baixo dele
sp.poisson.cdf(7, 12) todos os valores de 7 para baixo

d ) A probabilidade de que em uma hora qualquer cheguem menos de 7 clientes
P(k < 7) cdf direto pois cdf por padrão de um ponto para baixo dele
sp.poisson.cdf(6, 12)

e) A probabilidade de que em uma hora qualquer cheguem 7 clientes ou mais
P(k >= 7) 1 - cfd, pois preceisamos da parte maior ou igual (cauda de cima)
1 - sp.poisson.cdf(6, 12)

f) a probabilidade de que em uma hora qualquer cheguem mais de 7 clientes
P(k > 7) 1 - cdf, pois precisamos da parte maior (cauda de cima)
1 - sp.poisson.cdf(7, 12)
'''

# %%
# a)
# P(K = 4)
sp.poisson.pmf(4, 12)
# Out:
# 0.005308599473275576

# %%
# b)
# P(K = 7)
sp.poisson.pmf(7, 12)
# Out:
# 0.043682189951524654

# %%
#c) A probabilidade de que em uma hora qualquer cheguem 7 clientes ou menos
#P(k <= 7) cdf direto pois cdf por padrão de um ponto para baixo dele
sp.poisson.cdf(7, 12) #todos os valores de 7 para baixo
# Out:
# 0.08950449684017583

# %%
#d ) A probabilidade de que em uma hora qualquer cheguem menos de 7 clientes
#P(k < 7) cdf direto pois cdf por padrão de um ponto para baixo dele
sp.poisson.cdf(6, 12)
# Out:
# 0.04582230688865106

# %%
# e) A probabilidade de que em uma hora qualquer cheguem 7 clientes ou mais
# P(k >= 7) 1 - cfd, pois preceisamos da parte maior ou igual (cauda de cima)
1 - sp.poisson.cdf(6, 12)
# Out:
# 0.9541776931113489

# %%
# f) a probabilidade de que em uma hora qualquer cheguem mais de 7 clientes
# P(k > 7) 1 - cdf, pois precisamos da parte maior (cauda de cima)
1 - sp.poisson.cdf(7, 12)
# Out:
# 0.9104955031598242
