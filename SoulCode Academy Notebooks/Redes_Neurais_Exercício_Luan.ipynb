# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSZx9XGgSyCDGszLNwgNESBjO2jKZUDaRsYJs6J3tA1KteWd2Ne_RcuPDRz5y7Wak4Syl3l18fLZ4R6/pub?output=csv')
#Dataframe dos alunos de Portugal

# %%
df.head()
# Out:
#   escola sexo  idade tipo_endereco tamanho_familia status_pais  educ_mae  \
# 0     GP    F     18             U             GT3           A         4
# 1     GP    F     17             U             GT3           T         1
# 2     GP    F     15             U             LE3           T         1
# 3     GP    F     15             U             GT3           T         4
# 4     GP    F     16             U             GT3           T         3
#
#    educ_pai trab_mae  trab_pai  ... tempo_livre saidas  consumo_alcool_dia  \
# 0         4  at_home   teacher  ...           3      4                   1
# 1         1  at_home     other  ...           3      3                   1
# 2         1  at_home     other  ...           3      2                   2
# 3         2   health  services  ...           2      2                   1
# 4         3    other     other  ...           3      2                   1
#
#    consumo_alcool_fimsemana  estado_saude num_faltas nota_periodo1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   escola                        395 non-null    object
#  1   sexo                          395 non-null    object
#  2   idade                         395 non-null    int64
#  3   tipo_endereco                 395 non-null    object
#  4   tamanho_familia               395 non-null    object
#  5   status_pais                   395 non-null    object
#  6   educ_mae                      395 non-null    int64
#  7   educ_pai                      395 non-null    int64
#  8   trab_mae                      395 non-null    object
#  9   trab_pai                      395 non-null    object
#  10  motivo_escolha                395 non-null    object
#  11  responsavel                   395 non-null    object
# ...

# %%
df.drop('#N/D', axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

categorical_cols = df.select_dtypes(include=['object']).columns #selecionei os objetos da tabela

label_encoder = LabelEncoder() #transformei com o label encoder em inteiro
for col in categorical_cols:
    df[col] = label_encoder.fit_transform(df[col])

# %%
# Categorizando a Variável Alvo
df['Aprovado'] = (df['nota_final'] >= 10).astype(int)  # 1 se aprovado, 0 se reprovado

# %%
y = keras.utils.to_categorical(y)
y.shape
# Out:
# (395, 2, 2, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   escola                        395 non-null    int64
#  1   sexo                          395 non-null    int64
#  2   idade                         395 non-null    int64
#  3   tipo_endereco                 395 non-null    int64
#  4   tamanho_familia               395 non-null    int64
#  5   status_pais                   395 non-null    int64
#  6   educ_mae                      395 non-null    int64
#  7   educ_pai                      395 non-null    int64
#  8   trab_mae                      395 non-null    int64
#  9   trab_pai                      395 non-null    int64
#  10  motivo_escolha                395 non-null    int64
#  11  responsavel                   395 non-null    int64
#  12  tempo_viagem                  395 non-null    int64
# ...

# %%
# Converter variáveis categóricas para numéricas
label_encoder = LabelEncoder()
for col in X.select_dtypes(include=['object']).columns:
    x[col] = label_encoder.fit_transform(X[col])

# %%
# Definindo Variável:
X = df.drop('Aprovado', axis=1)
y = df['Aprovado']

# Dividir os dados em treino e teste
from sklearn.model_selection import train_test_split

#Definir X e Y Treino
X_treino, x_teste, y_treino, y_teste = train_test_split(X, y, test_size = 0.2, stratify = y, random_state=42)

# Se y for categórico:
if y.dtype == 'object':
    le = LabelEncoder()
    y = le.fit_transform(y)

# Se X tiver colunas categóricas:
X = pd.get_dummies(X)

# Escalar os dados
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from tensorflow import keras

# %%
modelo = keras.Sequential([keras.layers.Dense(units=1,input_shape=[32],name='neuronio')])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
modelo.summary()
# Out:
# Model: "sequential_33"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ neuronio (Dense)                     │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 33 (132.00 B)
#  Trainable params: 33 (132.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Verificando os pesos atribuídos incialmente
modelo.layers[0].get_weights()
# Out:
# [array([[-0.066991  ],
#         [ 0.30040365],
#         [ 0.21332568],
#         [-0.41345042],
#         [ 0.30553442],
#         [ 0.11803186],
#         [-0.12570724],
#         [ 0.08121639],
#         [-0.28853226],
#         [-0.22937809],
#         [-0.08878154],
#         [ 0.159078  ],
#         [-0.25666896],
#         [-0.16933852],
#         [-0.09494248],
#         [-0.33734834],
#         [-0.13776484],
#         [-0.38061285],
#         [-0.11394921],
#         [-0.32810697],
#         [ 0.01789597],
#         [-0.25103372],
#         [ 0.29016662],
#         [-0.16918197],
#         [-0.2017557 ],
#         [ 0.2794634 ],
#         [-0.05477744],
#         [ 0.30852592],
#         [-0.00212646],
#         [ 0.24058461],
#         [-0.4011618 ],
#         [ 0.26398456]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
# Verificando o bias inicialmente atribuído
pesos,bias = modelo.layers[0].get_weights()
print(pesos.shape)
pesos
# Out:
# (32, 1)
# array([[-0.066991  ],
#        [ 0.30040365],
#        [ 0.21332568],
#        [-0.41345042],
#        [ 0.30553442],
#        [ 0.11803186],
#        [-0.12570724],
#        [ 0.08121639],
#        [-0.28853226],
#        [-0.22937809],
#        [-0.08878154],
#        [ 0.159078  ],
#        [-0.25666896],
#        [-0.16933852],
#        [-0.09494248],
#        [-0.33734834],
#        [-0.13776484],
#        [-0.38061285],
#        [-0.11394921],
#        [-0.32810697],
#        [ 0.01789597],
#        [-0.25103372],
#        [ 0.29016662],
#        [-0.16918197],
#        [-0.2017557 ],
#        [ 0.2794634 ],
#        [-0.05477744],
#        [ 0.30852592],
#        [-0.00212646],
#        [ 0.24058461],
#        [-0.4011618 ],
#        [ 0.26398456]], dtype=float32)

# %%
print(bias.shape)
bias
# Out:
# (1,)
# array([0.], dtype=float32)

# %%
modelo = keras.Sequential([keras.layers.Dense(units=1,input_shape=[2],name='neuronio',
                                              kernel_initializer = keras.initializers.RandomNormal(),
                                              bias_initializer = keras.initializers.Ones())])
modelo.layers[0].get_weights()
# Out:
# [array([[0.03927204],
#         [0.02505608]], dtype=float32),
#  array([1.], dtype=float32)]

# %%
y
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 390    0
# 391    1
# 392    0
# 393    1
# 394    0
# Name: Aprovado, Length: 395, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(x=X.iloc[:,], y=X.iloc[:,1], hue=y, palette='tab10')
plt.xlabel('Não Aprovado',fontsize =16)
plt.ylabel('Aprovado', fontsize=16)
plt.title('Distribuição das Notas', fontsize = 18)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-356-0baef19f5b8b> in <cell line: 0>()
#       2 import seaborn as sns
#       3
# ----> 4 sns.scatterplot(x=X.iloc[:,], y=X.iloc[:,1], hue=y, palette='tab10')
#       5 plt.xlabel('Não Aprovado',fontsize =16)
#       6 plt.ylabel('Aprovado', fontsize=16)
#
# /usr/local/lib/python3.11/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     613 ):
#     614
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#
# /usr/local/lib/python3.11/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     394         )
#     395
# ...

# %%
sns.scatterplot(x=X.iloc[:,1], y=X.iloc[:,1], hue=y, palette='tab10')
plt.xlabel('Aprovado', fontsize = 16)
plt.ylabel('Não Aprovado', fontsize = 16)
plt.title('Distribuição Matemática', fontsize = 18)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-335-526c1532ddb1> in <cell line: 0>()
# ----> 1 sns.scatterplot(x=X.iloc[:,1], y=X.iloc[:,1], hue=y, palette='tab10')
#       2 plt.xlabel('Aprovado', fontsize = 16)
#       3 plt.ylabel('Não Aprovado', fontsize = 16)
#       4 plt.title('Distribuição Matemática', fontsize = 18)
#       5 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     613 ):
#     614
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#
# /usr/local/lib/python3.11/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     394         )
#     395
# ...

# %% [markdown]
# ## Categorização

# %%
y.shape
# Out:
# (395,)

# %%
y = keras.utils.to_categorical(y)
y.shape
# Out:
# (395, 2)

# %%
from keras.models import Sequential
from keras.layers import Dense, InputLayer
from keras.utils import to_categorical

modelo = keras.Sequential([
    InputLayer(shape=(33,), name='entrada'),  # Corrigido aqui!
    Dense(512, activation='relu', name='oculta',
          kernel_initializer='random_normal'),
    Dense(2, activation='softmax', name='saida')  # 2 saídas, pois y.shape = (395, 2)
])

# %%
modelo.summary()
# Out:
# Model: "sequential_35"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ oculta (Dense)                       │ (None, 512)                 │          17,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ saida (Dense)                        │ (None, 2)                   │           1,026 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,434 (72.01 KB)
#  Trainable params: 18,434 (72.01 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
modelo.compile(loss = 'categorical_crossentropy',
               optimizer = 'rmsprop',
               metrics = ['categorical_accuracy'])

# %%
# 1. Importando as bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# 3. Padronizando os dados (muito importante antes de aplicar PCA)
escalador = StandardScaler()
dados_padronizados = escalador.fit_transform(df)

# 4. Aplicando o PCA
pca = PCA(n_components=2)  # Queremos reduzir para 2 componentes
dados_pca = pca.fit_transform(dados_padronizados)

# 5. Transformando o resultado em um novo DataFrame
df_pca = pd.DataFrame(data=dados_pca, columns=['Componente 1', 'Componente 2'])
display(df_pca)

# 6. Explicando a variância explicada
print("\nVariância explicada por cada componente:")
print(pca.explained_variance_ratio_)
# Out:
#      Componente 1  Componente 2
# 0       -2.072989     -1.814807
# 1       -2.695065     -2.340105
# 2       -1.838400     -1.010174
# 3        2.698274     -1.848474
# 4        0.299114     -1.673258
# ..            ...           ...
# 390     -3.244702      3.725568
# 391      0.294261      4.633557
# 392     -5.055868      3.024596
# 393     -1.131030      3.754427
# 394     -2.631166      1.727473
#
# [395 rows x 2 columns]
# Variância explicada por cada componente:
# [0.12698129 0.0758097 ]

# %%
print(X_scaled.shape)
print(y.shape)
# Out:
# (395, 33)
# (395, 2)

# %%
modelo.compile(loss = 'categorical_crossentropy',
               optimizer = 'rmsprop',
               metrics = ['categorical_accuracy'])

# %%
historico = modelo.fit(
    X_scaled, y,
    epochs=epocas,
    validation_split=0.3
)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - categorical_accuracy: 0.5939 - loss: 0.6682 - val_categorical_accuracy: 0.8403 - val_loss: 0.4360
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - categorical_accuracy: 0.9128 - loss: 0.3348 - val_categorical_accuracy: 0.8824 - val_loss: 0.3424
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.9272 - loss: 0.2538 - val_categorical_accuracy: 0.9076 - val_loss: 0.2936
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - categorical_accuracy: 0.9551 - loss: 0.1851 - val_categorical_accuracy: 0.9160 - val_loss: 0.2564
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9630 - loss: 0.1650 - val_categorical_accuracy: 0.9076 - val_loss: 0.2334
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 0.9815 - loss: 0.1174 - val_categorical_accuracy: 0.9160 - val_loss: 0.2202
# Epoch 7/100
# ...

# %%
import pandas as pd

pd.DataFrame(historico.history).plot()
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(14,5))
ax[0].plot(historico.history['loss'], color='#111487', linewidth=3, label="Perda de treinamento")
ax[0].plot(historico.history['val_loss'], color='#EFA316', linewidth=3, label="Perda da validação") # Removed axes=ax[0]
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(historico.history['categorical_accuracy'], color='#111487', linewidth=3, label="Acurácia de treinamento")
ax[1].plot(historico.history['val_categorical_accuracy'], color='#EFA316', linewidth=3, label="Acurácia de validação")
legend = ax[1].legend(loc='best', shadow=True)

plt.suptitle('Desempenho do treinamento', fontsize = 18)
plt.show()
