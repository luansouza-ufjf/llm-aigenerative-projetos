# %%
import pandas as pd
import matplotlib.pyplot as plt
from  sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression

# %%
# Regressão
x,y = make_regression(n_samples=400, n_features=1, noise=10)
plt.scatter(x,y);

# %%
modelo = LinearRegression()
modelo.fit(x,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y, label = "Dados Históricos")
plt.plot(x, a_coeff*x + l_coeff , color='red', label ="Linha de Predição")
plt.scatter(1.5, l_coeff + a_coeff*1.5, color='green')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-64f5d5982a76> in <cell line: 0>()
#       1 plt.scatter(x,y, label = "Dados Históricos")
# ----> 2 plt.plot(x, a_coeff*x + l_coeff , color='red', label ="Linha de Predição")
#       3 plt.scatter(1.5, l_coeff + a_coeff*1.5, color='green')
#       4 plt.legend()
#       5 plt.show()
#
# NameError: name 'l_coeff' is not defined
